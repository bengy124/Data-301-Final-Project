# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import project_functions as pf

df = pf.load_and_process('../../data/raw/games-features.csv')
df2 = pf.Column_var_sort(df,'Owners',False)
dfrated = df2[df2.Rating != 0]
corr = df.corr()

# %% [markdown]
# # Graphs From Entire set of EDAs

# %% [markdown]
# ## Austin's Graphs

# %% [markdown]
# ## Describes the Price vs the amount of owners with a regression line

# %%
dfo = df[(df["Owners"]<20000000)&(df["PriceFinal"]<100)]
pricevowners = sns.regplot(data=dfo,x="PriceFinal",y="Owners", color='blue')

# %% [markdown]
# ## These next graphs describe the distribution of the raitings per genre. The First is Adventure

# %%
adventure = pf.genreratingplot(df,"GenreIsAdventure")

# %% [markdown]
# ## Action Genre

# %%
action = pf.genreratingplot(df,"GenreIsAction")

# %% [markdown]
# ## Indie Genre

# %%
indie = pf.genreratingplot(df,"GenreIsIndie")

# %% [markdown]
# ## Casual Genre

# %%
casual = pf.genreratingplot(df,"GenreIsCasual")

# %% [markdown]
# ## Describes the rating vs the amount of recomendations with a regression line

# %%
ratingvowners = sns.regplot(data=dfrated[dfrated["Owners"]<20000000],x="Rating",y="Owners", scatter_kws={"color": "navy"}, line_kws={"color": "red"})
ratingvrecommend = sns.regplot(data=dfrated[(dfrated["Recommendations"]<300000)&(dfrated["Recommendations"]>5000)],x="Rating",y="Recommendations", scatter_kws={"color": "navy"}, line_kws={"color": "red"})

# %% [markdown]
# ## Bengy's Graphs

# %% [markdown]
# ## This is a heatmap describing the correlation between the genres, massively multiplayer and free to play have the greatest correlation

# %%
plt.figure(figsize = (16,5))
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, annot=True, cmap=sns.diverging_palette(220, 20, as_cmap=True))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Scatter plot to describe Price initial vs the rating

# %%
df.plot(kind='scatter', x='PriceInitial', y='Rating')
# Out:
# <AxesSubplot:xlabel='PriceInitial', ylabel='Rating'>

# %% [markdown]
# ## Scatter plot to describe the price final vs Rating

# %%
df.plot(kind='scatter', x='PriceFinal', y='Rating')
# Out:
# <AxesSubplot:xlabel='PriceFinal', ylabel='Rating'>

# %% [markdown]
# ## Cawston's Graphs

# %% [markdown]
# ## Describes the rating vs the owners

# %%
df.plot(x="Rating", y="Owners", kind="scatter")
# Out:
# <AxesSubplot:xlabel='Rating', ylabel='Owners'>

# %% [markdown]
# ## The final price vs owners

# %%
df.plot(x="PriceFinal", y="Owners", kind="scatter")
# Out:
# <AxesSubplot:xlabel='PriceFinal', ylabel='Owners'>

# %% [markdown]
# ## Describes the Recomendations vs Owners

# %%
df.plot(x="Recommendations", y="Owners", kind="scatter")
# Out:
# <AxesSubplot:xlabel='Recommendations', ylabel='Owners'>

# %% [markdown]
# ## Describes the Recomendations vs Owners with a relplot

# %%
sns.relplot(data=df, y="Owners", x="Recommendations", kind="line", ci=1)

# %% [markdown]
# ## Describes the recomendations vs the amount of owners with a regression line

# %%
sns.regplot(y="Owners", x="Recommendations", data=df)
# Out:
# <AxesSubplot:xlabel='Recommendations', ylabel='Owners'>

# %% [markdown]
# ## More plots to visually see the Owners vs ratings

# %%
sns.displot(x="Rating", y="Owners", data=df)

# %% [markdown]
# ## Describes the distribution of games over genres

# %%
pf.Genrecount(df)
# Out:
# Total Games :  13038  Indie Games :  7780  Action Games :  5633  Casual Games :  3564  Adventure Games :  4319  Strategy Games:  2623 RPG  :  2087  Simulation Games :  2102  Early Access :  1438  Free To Play :  665  Sports :  541  Racing :  476  Massively Multiplayer :   389

# %% [markdown]
# ## Describes the revenune distribution for the genres

# %%
pf.plotRevenue(df)
# Out:
# Total  :  25094.869310830007  Indie  :  6353.22448572  Action  :  16578.13137856  Casual  :  1090.51912292  Adventure :  6796.093231229999  Strategy :  5110.410997350001 RPG  :  5068.28928216  Simulation  :  3228.5843055900004  Early Access :  1089.50451871  Free To Play :  1.2510462500000001  Sports :  736.49216724  Racing :  771.73085653  Massively Multiplayer :   630.50235201

# %% [markdown]
# ## Describes distribution of owners over the different genres

# %%
pf.plotOwners(df)
# Out:
# Total Owners :  2217998757  Indie :  731152113  Action  :  1512554753  Casual  :  240120444  Adventure  :  550881684  Strategy:  477453337 RPG  :  459321917  Simulation  :  273863846  Early Access :  162389801  Free To Play :  574553200  Sports :  59135546  Racing :  50611953  Massively Multiplayer :   229371663

# %% [markdown]
# # Tables

# %% [markdown]
# ## Bengy's Tables

# %% [markdown]
# ## This table gives values that we can compare in our graphs

# %%
df.describe()
# Out:
#              Rating  Recommendations        Owners  PriceInitial  \
# count  13038.000000     1.303800e+04  1.303800e+04  13038.000000
# mean      12.585903     1.205992e+03  1.701180e+05      8.474556
# std       27.777402     1.535934e+04  1.140492e+06     10.265017
# min        0.000000     0.000000e+00  0.000000e+00      0.000000
# 25%        0.000000     0.000000e+00  8.970000e+02      1.990000
# 50%        0.000000     0.000000e+00  9.864000e+03      5.990000
# 75%        0.000000     2.520000e+02  6.277200e+04      9.990000
# max       96.000000     1.427633e+06  9.068758e+07    234.990000
#
#          PriceFinal  RevenueMillions
# count  13038.000000     13038.000000
# mean       8.126447         1.924748
# std        9.234561        11.458730
# min        0.000000         0.000000
# 25%        1.990000         0.000000
# 50%        4.990000         0.034007
# 75%        9.990000         0.284975
# max      234.990000       387.239008

# %% [markdown]
# # Conclusions

# %% [markdown]
# #### We can see some of our main areas of data where we can use to analyze our data set, such as the rating vs owners and using the price to analyze the distribution of games over the owners and genres. Our EDA was used to test out graphs and plots for our data to see what conclusions we could make imedieatly from our plots. We found many useful plots many of which are in the plot section of the combined EDA.
