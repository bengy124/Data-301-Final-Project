# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as ply
import seaborn as sns
import project_functions
## Importing using the relative path kept giving errors
df = project_functions.load_and_process('../../data/raw/games-features.csv')
df2 = project_functions.Column_var_sort(df,'Owners',False)
dfrated = df2[df2.Rating != 0]
dfrindie = dfrated[dfrated.GenreIsIndie == True]
dfraction = dfrated[dfrated.GenreIsAction == True]
dfrcasual = dfrated[dfrated.GenreIsCasual == True]
indiemean = dfrindie['Rating'].mean()
actionmean = dfraction['Rating'].mean()
casualmean = dfrcasual['Rating'].mean()

# %%
dfowned = df2[df2.Owners != 0]
dfrev = dfowned.assign(RevenueMillions=dfowned.Owners*dfowned.PriceFinal/1000000)
dfrevsort = project_functions.Column_var_sort(dfrev,'RevenueMillions',False)
dfrevsort2 = dfrevsort[dfrevsort.PriceFinal != 0]
dfrevsort2.head()
highprice = project_functions.Column_var_sort(df,'PriceFinal',False)
highprice
# Out:
#                                         Games  ReleaseDate  Rating  \
# 4030   SolidFace Parametric CAD Modeler 2D/3D  Dec 22 2014       0
# 3222        VEGAS Pro 13 Edit - Steam Powered   Nov 2 2015       0
# 5017                      Atavism MMO Creator  Jan 20 2015       0
# 12271         VEGAS Pro 14 Edit Steam Edition  Sep 30 2016       0
# 12838          Marvelous Designer 6 For Steam  Nov 23 2016       0
# ...                                       ...          ...     ...
# 5652                         Bloodwood Reload   Nov 2 2015       0
# 5642                         Red Stone Online     Apr 2015       0
# 5641                                  Alganon  May 19 2015       0
# 10958                            Unknown Fate  Coming 2017       0
# 13356                        Ghostlight Manor  Dec 12 2016       0
#
#        Recommendations  Owners  CategoryInAppPurchase  GenreIsIndie  \
# 4030                 0       0                  False         False
# ...

# %%
pricevowners = ply.plot(df2.Owners,df2.PriceFinal,'o', color='blue')
## Drop outliers and try again
## Modify function to remove all non-games
## Then remove the column
