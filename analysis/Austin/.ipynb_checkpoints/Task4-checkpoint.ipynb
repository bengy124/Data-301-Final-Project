# %%
import pandas as pd
import numpy as np
import project_functions
## Importing using the relative path kept giving errors
df = project_functions.load_and_process('../../data/raw/games-features.csv')
df2 = project_functions.Column_var_sort(df,'Owners',False)
df2
# Out:
#                                   Games  ReleaseDate  Rating  Recommendations  \
# 23                               Dota 2   Jul 9 2013      90           590480
# 20                      Team Fortress 2  Oct 10 2007      92           383949
# 4028                           Unturned   Jul 7 2014       0           222301
# 27     Counter-Strike: Global Offensive  Aug 21 2012      83          1427633
# 22                        Left 4 Dead 2  Nov 16 2009      89           140726
# ...                                 ...          ...     ...              ...
# 11496                           Torsion  Aug 31 2016       0                0
# 9645                     Tower Dwellers  Aug 23 2016       0                0
# 3062                 I Want To Be Human  Apr 15 2016      53                0
# 9622                          Protonwar   Jul 5 2016       0                0
# 13356                  Ghostlight Manor  Dec 12 2016       0                0
#
# ...
