# %%
import pandas as pd
import numpy as np

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Task 3
import project_functions 
df = project_functions.load_and_process('../../data/raw/games-features.csv')
df
# Out:
#                            Games  ReleaseDate  Rating  Recommendations  \
# 0                 Counter-Strike   Nov 1 2000      88            68991
# 1          Team Fortress Classic   Apr 1 1999       0             2439
# 2                  Day of Defeat   May 1 2003      79             2319
# 3             Deathmatch Classic   Jun 1 2001       0              888
# 4      Half-Life: Opposing Force   Nov 1 1999       0             2934
# ...                          ...          ...     ...              ...
# 13352              Baseball Riot  Jan 17 2017       0                0
# 13353                  Passage 4  Dec 13 2016       0                0
# 13354                 Piximalism  Sep 26 2019       0                0
# 13355                 Technoball  Dec 12 2016       0                0
# 13356           Ghostlight Manor  Dec 12 2016       0                0
#
#          Owners  GenreIsIndie  GenreIsAction  GenreIsAdventure  GenreIsCasual  \
# ...

# %%
#Task 4
df.describe(exclude=[np.number]).T
# Out:
#                              count unique                   top   freq
# Games                        13357  13199  Train Simulator 2016      9
# ReleaseDate                  13357   2117           Aug 22 2016    241
# GenreIsIndie                 13357      2                  True   7780
# GenreIsAction                13357      2                 False   7724
# GenreIsAdventure             13357      2                 False   9038
# GenreIsCasual                13357      2                 False   9793
# GenreIsStrategy              13357      2                 False  10734
# GenreIsRPG                   13357      2                 False  11270
# GenreIsSimulation            13357      2                 False  11255
# GenreIsEarlyAccess           13357      2                 False  11887
# GenreIsFreeToPlay            13357      2                 False  12692
# GenreIsSports                13357      2                 False  12816
# ...

# %%
df.describe()
# Looking at this table the most of use sections that could be explored further are the mean prices and ratings.
# Out:
#              Rating  Recommendations        Owners  PriceInitial    PriceFinal
# count  13357.000000     1.335700e+04  1.335700e+04  13357.000000  13357.000000
# mean      12.285319     1.180463e+03  1.668493e+05      9.155717      8.798596
# std       27.510876     1.517606e+04  1.127122e+06     14.345029     13.606061
# min        0.000000     0.000000e+00  0.000000e+00      0.000000      0.000000
# 25%        0.000000     0.000000e+00  8.970000e+02      1.990000      1.990000
# 50%        0.000000     0.000000e+00  9.506000e+03      5.990000      5.990000
# 75%        0.000000     2.430000e+02  6.044100e+04      9.990000      9.990000
# max       96.000000     1.427633e+06  9.068758e+07    449.990000    449.990000

# %%
corr = df.corr()
plt.figure(figsize = (16,5))
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, annot=True, cmap=sns.diverging_palette(220, 20, as_cmap=True))
#This plot shows for any correlations between each numerical column. 
#Between genres games that are massively multiplayer and free to play have the greatest correlation
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='scatter', x='PriceInitial', y='Rating')
# Out:
# <AxesSubplot:xlabel='PriceInitial', ylabel='Rating'>

# %%
df.plot(kind='scatter', x='PriceFinal', y='Rating')
# Out:
# <AxesSubplot:xlabel='PriceFinal', ylabel='Rating'>

# %%
#These 2 scatterplots show is there is any noticible relationship between prices and rating. 
#Games cheaper in price are more likely to be rated than those that are more expensive
