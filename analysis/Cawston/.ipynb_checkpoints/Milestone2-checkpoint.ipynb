# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import project_functions
df=project_functions.load_and_process('../../data/raw/games-features.csv')
df3=project_functions.Column_var_sort(df,"Recommendations", False)
df=df*1
import matplotlib as plt
df.plot(x="Rating", y="Owners", kind="scatter")
df.plot(x="PriceFinal", y="Owners", kind="scatter")
df.plot(x="Recommendations", y="Owners", kind="scatter")
print("done")
sns.relplot(data=df, y="Owners", x="Recommendations", kind="line", ci=1)
sns.regplot(y="Owners", x="Recommendations", data=df)
sns.kdeplot(x="Rating", y="Owners", data=df)
sns.displot(x="Rating", y="Owners", data=df)
# Out:
# done

# %% [markdown]
# ### Plots
#     The plots are a definite work in progress as of now as I am still working on a method to apply to the data to obtain better plots.
#     The code simply takes one of the functions given in project_functions to clean the data than applying plots to the genres and the price to get information on the ownership of the   games.

# %%
project_functions.plotOwners(df)
# Out:
# Total Games :  2228605730  Indie :  731152113  Action  :  1512554753  Casual  :  240120444  Adventure  :  550881684  Strategy:  477453337 RPG  :  459321917  Simulation  :  273863846  Early Access :  162593353  Free To Play :  574553200  Sports :  59135546  Racing :  50611953  Massively Multiplayer :   229371663

# %% [markdown]
# ###

# %%
project_functions.Genrecount(df)
# Out:
# Total Games :  13357  Indie Games :  7780  Action Games :  5633  Casual Games :  3564  Adventure Games :  4319  Strategy Games:  2623 RPG  :  2087  Simulation Games :  2102  Early Access :  1470  Free To Play :  665  Sports :  541  Racing :  476  Massively Multiplayer :   389

# %%
project_functions.plotRevenue(df)
# Out:
# Total  :  25217.5747786  Indie  :  6353.22448572  Action  :  16578.13137856  Casual  :  1090.51912292  Adventure :  6796.093231229999  Strategy :  5110.410997350001 RPG  :  5068.28928216  Simulation  :  3228.5843055900004  Early Access :  1089.79911586  Free To Play :  1.2510462500000001  Sports :  736.49216724  Racing :  771.73085653  Massively Multiplayer :   630.50235201
